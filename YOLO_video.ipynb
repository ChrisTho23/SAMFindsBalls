# %%
pip install opencv-python ultralytics

# %%
def predict(chosen_model, img, classes=[], conf=0.5):
    if classes:
        results = chosen_model.predict(img, classes=classes, conf=conf)
    else:
        results = chosen_model.predict(img, conf=conf)

    return results

def predict_and_detect(chosen_model, img, classes=[], conf=0.5, rectangle_thickness=2, text_thickness=1):
    results = predict(chosen_model, img, classes, conf=conf)
    for result in results:
        for box in result.boxes:
            cv2.rectangle(img, (int(box.xyxy[0][0]), int(box.xyxy[0][1])),
                          (int(box.xyxy[0][2]), int(box.xyxy[0][3])), (255, 0, 0), rectangle_thickness)
            cv2.putText(img, f"{result.names[int(box.cls[0])]}",
                        (int(box.xyxy[0][0]), int(box.xyxy[0][1]) - 10),
                        cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 0), text_thickness)
    return img, results

# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov10x.pt")

# defining function for creating a writer (for mp4 videos)
def create_video_writer(video_cap, output_filename):
    # grab the width, height, and fps of the frames in the video stream.
    frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(video_cap.get(cv2.CAP_PROP_FPS))
    # initialize the FourCC and a video writer object
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    writer = cv2.VideoWriter(output_filename, fourcc, fps,
                             (frame_width, frame_height))
    return writer

# %%
output_filename = "car_race_segment"
writer = create_video_writer(cap, output_filename)

video_path = "/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/data/Carrera_de_autos.mov"
cap = cv2.VideoCapture(video_path)
while True:
    success, img = cap.read()
    if not success:
        break
    result_img, _ = predict_and_detect(model, img, classes=[], conf=0.5)
    writer.write(result_img)
    cv2.imshow("Image", result_img)
    
    cv2.waitKey(1)
writer.release()
# Out:
# [ WARN:0@703.624] global cap.cpp:645 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.10.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_images.cpp:430: error: (-215:Assertion failed) !filename_pattern.empty() in function 'open'
# 0: 352x640 5 cars, 2928.9ms
# Speed: 30.3ms preprocess, 2928.9ms inference, 16.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 2140.4ms
# Speed: 8.8ms preprocess, 2140.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1825.5ms
# Speed: 8.6ms preprocess, 1825.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1768.4ms
# Speed: 3.6ms preprocess, 1768.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1911.3ms
# Speed: 3.7ms preprocess, 1911.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1856.2ms
# Speed: 3.9ms preprocess, 1856.2ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1771.0ms
# Speed: 5.1ms preprocess, 1771.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1927.9ms
# Speed: 4.3ms preprocess, 1927.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1771.4ms
# Speed: 4.0ms preprocess, 1771.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1745.6ms
# Speed: 3.8ms preprocess, 1745.6ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 2836.8ms
# Speed: 3.9ms preprocess, 2836.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1878.7ms
# Speed: 8.8ms preprocess, 1878.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1818.7ms
# Speed: 3.7ms preprocess, 1818.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1742.3ms
# Speed: 4.3ms preprocess, 1742.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1680.7ms
# Speed: 5.4ms preprocess, 1680.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1677.1ms
# Speed: 5.6ms preprocess, 1677.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1839.2ms
# Speed: 4.0ms preprocess, 1839.2ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1838.0ms
# Speed: 3.3ms preprocess, 1838.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1687.7ms
# Speed: 4.9ms preprocess, 1687.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1812.7ms
# Speed: 3.9ms preprocess, 1812.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1751.8ms
# Speed: 5.1ms preprocess, 1751.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1669.8ms
# Speed: 14.5ms preprocess, 1669.8ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1673.0ms
# Speed: 4.5ms preprocess, 1673.0ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1794.7ms
# Speed: 3.7ms preprocess, 1794.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1974.4ms
# Speed: 5.3ms preprocess, 1974.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 2066.5ms
# Speed: 7.2ms preprocess, 2066.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1985.9ms
# Speed: 4.2ms preprocess, 1985.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1842.0ms
# Speed: 7.3ms preprocess, 1842.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1923.3ms
# Speed: 4.2ms preprocess, 1923.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1674.3ms
# Speed: 3.6ms preprocess, 1674.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1705.5ms
# Speed: 5.0ms preprocess, 1705.5ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1942.0ms
# Speed: 4.7ms preprocess, 1942.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1820.4ms
# Speed: 5.9ms preprocess, 1820.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1791.2ms
# Speed: 4.3ms preprocess, 1791.2ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 2044.2ms
# Speed: 5.5ms preprocess, 2044.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1853.4ms
# Speed: 5.9ms preprocess, 1853.4ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 4244.6ms
# Speed: 6.5ms preprocess, 4244.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 6836.1ms
# Speed: 7.1ms preprocess, 6836.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 2602.9ms
# Speed: 6.6ms preprocess, 2602.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1818.0ms
# Speed: 7.5ms preprocess, 1818.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1752.6ms
# Speed: 7.4ms preprocess, 1752.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1716.3ms
# Speed: 10.6ms preprocess, 1716.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1941.2ms
# Speed: 10.1ms preprocess, 1941.2ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1775.1ms
# Speed: 3.9ms preprocess, 1775.1ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 2029.2ms
# Speed: 3.2ms preprocess, 2029.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1852.4ms
# Speed: 11.6ms preprocess, 1852.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1818.4ms
# Speed: 9.2ms preprocess, 1818.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 4018.5ms
# Speed: 3.9ms preprocess, 4018.5ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1837.3ms
# Speed: 4.1ms preprocess, 1837.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 2318.7ms
# Speed: 4.4ms preprocess, 2318.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1933.9ms
# Speed: 13.8ms preprocess, 1933.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1732.0ms
# Speed: 3.9ms preprocess, 1732.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1671.6ms
# Speed: 6.5ms preprocess, 1671.6ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1699.0ms
# Speed: 3.4ms preprocess, 1699.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1657.3ms
# Speed: 3.6ms preprocess, 1657.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1698.7ms
# Speed: 7.0ms preprocess, 1698.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1926.5ms
# Speed: 8.3ms preprocess, 1926.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 2210.5ms
# Speed: 4.4ms preprocess, 2210.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 2006.8ms
# Speed: 5.0ms preprocess, 2006.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1798.7ms
# Speed: 3.9ms preprocess, 1798.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 1802.6ms
# Speed: 13.9ms preprocess, 1802.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 cars, 2046.4ms
# Speed: 3.3ms preprocess, 2046.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 2185.0ms
# Speed: 5.4ms preprocess, 2185.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 3471.2ms
# Speed: 8.0ms preprocess, 3471.2ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 4451.6ms
# Speed: 27.1ms preprocess, 4451.6ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 3163.4ms
# Speed: 11.8ms preprocess, 3163.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# /Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb Celda 13 line 1
#
#       <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> if not success:
#
#       <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     break
#
# ---> <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a> result_img, _ = predict_and_detect(model, img, classes=[], conf=0.5)
#
#      <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a> writer.write(result_img)
#
#      <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a> cv2.imshow("Image", result_img)
#
#
#
# /Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb Celda 13 line 1
#
#       <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> def predict_and_detect(chosen_model, img, classes=[], conf=0.5, rectangle_thickness=2, text_thickness=1):
#
# ---> <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a>     results = predict(chosen_model, img, classes, conf=conf)
#
#      <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>     for result in results:
#
#      <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a>         for box in result.boxes:
#
#
#
# /Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb Celda 13 line 5
#
#       <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     results = chosen_model.predict(img, classes=classes, conf=conf)
#
#       <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> else:
#
# ----> <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     results = chosen_model.predict(img, conf=conf)
#
#       <a href='vscode-notebook-cell:/Users/alvarocalafellfernandezdepierola/Desktop/SAM2/SAMFindsBalls/YOLO.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> return results
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/engine/model.py:563, in Model.predict(self, source, stream, predictor, **kwargs)
#
#     561 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#
#     562     self.predictor.set_prompts(prompts)
#
# --> 563 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#
#     166     return self.stream_inference(source, model, *args, **kwargs)
#
#     167 else:
#
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#
#      32 try:
#
#      33     # Issuing `None` to a generator fires it up
#
#      34     with ctx_factory():
#
# ---> 35         response = gen.send(None)
#
#      37     while True:
#
#      38         try:
#
#      39             # Forward the response to our caller and get its next request
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#
#     252 # Inference
#
#     253 with profilers[1]:
#
# --> 254     preds = self.inference(im, *args, **kwargs)
#
#     255     if self.args.embed:
#
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#
#     136 """Runs inference on a given image using the specified model and arguments."""
#
#     137 visualize = (
#
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#
#     139     if self.args.visualize and (not self.source_type.tensor)
#
#     140     else False
#
#     141 )
#
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1510 else:
#
# -> 1511     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1516 # this function, and just call forward.
#
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1520     return forward_call(*args, **kwargs)
#
#    1522 try:
#
#    1523     result = None
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/nn/autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#
#     454 # PyTorch
#
#     455 if self.pt or self.nn_module:
#
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#
#     458 # TorchScript
#
#     459 elif self.jit:
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1510 else:
#
# -> 1511     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1516 # this function, and just call forward.
#
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1520     return forward_call(*args, **kwargs)
#
#    1522 try:
#
#    1523     result = None
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/nn/tasks.py:102, in BaseModel.forward(self, x, *args, **kwargs)
#
#     100 if isinstance(x, dict):  # for cases of training and validating while training.
#
#     101     return self.loss(x, *args, **kwargs)
#
# --> 102 return self.predict(x, *args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/nn/tasks.py:120, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#
#     118 if augment:
#
#     119     return self._predict_augment(x)
#
# --> 120 return self._predict_once(x, profile, visualize, embed)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/nn/tasks.py:141, in BaseModel._predict_once(self, x, profile, visualize, embed)
#
#     139 if profile:
#
#     140     self._profile_one_layer(m, x, dt)
#
# --> 141 x = m(x)  # run
#
#     142 y.append(x if m.i in self.save else None)  # save output
#
#     143 if visualize:
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1510 else:
#
# -> 1511     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1516 # this function, and just call forward.
#
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1520     return forward_call(*args, **kwargs)
#
#    1522 try:
#
#    1523     result = None
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:240, in C2f.forward(self, x)
#
#     238 y = list(self.cv1(x).chunk(2, 1))
#
#     239 y.extend(m(y[-1]) for m in self.m)
#
# --> 240 return self.cv2(torch.cat(y, 1))
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1510 else:
#
# -> 1511     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1516 # this function, and just call forward.
#
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1520     return forward_call(*args, **kwargs)
#
#    1522 try:
#
#    1523     result = None
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#
#      52 def forward_fuse(self, x):
#
#      53     """Perform transposed convolution of 2D data."""
#
# ---> 54     return self.act(self.conv(x))
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1510 else:
#
# -> 1511     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1516 # this function, and just call forward.
#
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1520     return forward_call(*args, **kwargs)
#
#    1522 try:
#
#    1523     result = None
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/modules/activation.py:393, in SiLU.forward(self, input)
#
#     392 def forward(self, input: Tensor) -> Tensor:
#
# --> 393     return F.silu(input, inplace=self.inplace)
#
#
#
# File ~/opt/anaconda3/envs/sam2/lib/python3.9/site-packages/torch/nn/functional.py:2074, in silu(input, inplace)
#
#    2072     return handle_torch_function(silu, (input,), input, inplace=inplace)
#
#    2073 if inplace:
#
# -> 2074     return torch._C._nn.silu_(input)
#
#    2075 return torch._C._nn.silu(input)
#
#
#
# KeyboardInterrupt:
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.
